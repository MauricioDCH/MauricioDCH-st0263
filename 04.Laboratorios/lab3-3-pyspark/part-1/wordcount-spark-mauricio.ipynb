# %%
sc
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>2</td><td>application_1731892482843_0003</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-59-169.ec2.internal:20888/proxy/application_1731892482843_0003/">Link</a></td><td><a target="_blank" href="http://ip-172-31-48-44.ec2.internal:8042/node/containerlogs/container_1731892482843_0003_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <SparkContext master=yarn appName=livy-session-2>

# %%
# WORDCOUNT COMPACTO
files_rdd = sc.textFile("s3://datasets-mauricio/datasets/gutenberg-small/*.txt")
#files_rdd = sc.textFile("hdfs:///user/hadoop/datasets/gutenberg-small/*.txt")
wc_unsort = files_rdd.flatMap(lambda line: line.split()).map(lambda word: (word, 1)).reduceByKey(lambda a, b: a + b)
wc = wc_unsort.sortBy(lambda a: -a[1])
for tupla in wc.take(10):
        print(tupla)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('the', 44647)
# ('of', 28020)
# ('to', 23208)
# ('and', 20444)
# ('in', 13174)
# ('that', 12265)
# ('I', 10880)
# ('a', 10431)
# ('is', 7776)
# ('be', 7148)

# %%
for f in files_rdd.take(10):
    print(f)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# LINCOLN LETTERS
#
# By Abraham Lincoln
#
#
# Published by The Bibilophile Society

# %%
tokens = files_rdd.flatMap(lambda line: line.split())
for t in tokens.take(10):
    print(t)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# LINCOLN
# LETTERS
# By
# Abraham
# Lincoln
# Published
# by
# The
# Bibilophile
# Society

# %%
wc1 = tokens.map(lambda word: (word, 1))
for c in wc1.take(10):
    print(c)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('LINCOLN', 1)
# ('LETTERS', 1)
# ('By', 1)
# ('Abraham', 1)
# ('Lincoln', 1)
# ('Published', 1)
# ('by', 1)
# ('The', 1)
# ('Bibilophile', 1)
# ('Society', 1)

# %%
wc = wc1.reduceByKey(lambda a, b: a + b)
for c in wc.take(10):
    print(c)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('thoroughly', 15)
# ('themselves', 192)
# ('them.', 371)
# ('letter', 312)
# ('A.', 1456)
# ('ORIGINALS', 1)
# ('THEY', 1)
# ('sum', 59)
# ('singular', 18)
# ('let', 414)

# %%
wcsort = wc.sortBy(lambda a: -a[1])
for c in wcsort.take(10):
    print(c)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# ('the', 44647)
# ('of', 28020)
# ('to', 23208)
# ('and', 20444)
# ('in', 13174)
# ('that', 12265)
# ('I', 10880)
# ('a', 10431)
# ('is', 7776)
# ('be', 7148)

# %%
#salvar los datos de salida, fijarse que no exista: hdfs:///tmp/<your-username>wcout10
wc.coalesce(1).saveAsTextFile("hdfs:///tmp/wcout10")
#si esta trabajando en aws (igual verifique que no exista previamente wcout10):
wc.coalesce(1).saveAsTextFile("s3://datasets-mauricio/wcout10")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%configure -f
# {
#     "conf": {
#         "spark.pyspark.python": "python3",
#         "spark.pyspark.virtualenv.enabled": "true",
#         "spark.pyspark.virtualenv.type": "native",
#         "spark.pyspark.virtualenv.bin.path": "/usr/bin/virtualenv"
#     }
# }
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>6</td><td>application_1731892482843_0007</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-59-169.ec2.internal:20888/proxy/application_1731892482843_0007/">Link</a></td><td><a target="_blank" href="http://ip-172-31-48-44.ec2.internal:8042/node/containerlogs/container_1731892482843_0007_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# Current session configs: <tt>{'conf': {'spark.pyspark.python': 'python3', 'spark.pyspark.virtualenv.enabled': 'true', 'spark.pyspark.virtualenv.type': 'native', 'spark.pyspark.virtualenv.bin.path': '/usr/bin/virtualenv'}, 'proxyUser': 'jovyan', 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>6</td><td>application_1731892482843_0007</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-59-169.ec2.internal:20888/proxy/application_1731892482843_0007/">Link</a></td><td><a target="_blank" href="http://ip-172-31-48-44.ec2.internal:8042/node/containerlogs/container_1731892482843_0007_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>

# %%
sc
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# <SparkContext master=yarn appName=livy-session-6>

# %%
sc.list_packages()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Package              Version
# -------------------- ----------
# appdirs              1.4.4
# attrs                20.3.0
# aws-cfn-bootstrap    2.0
# awscli               2.15.30
# awscrt               0.19.19
# Babel                2.9.1
# beautifulsoup4       4.9.3
# boto                 2.49.0
# cffi                 1.14.5
# chardet              4.0.0
# chevron              0.13.1
# click                8.1.7
# cloud-init           22.2.2
# colorama             0.4.4
# configobj            5.0.6
# cryptography         36.0.1
# dbus-python          1.2.18
# distlib              0.3.1
# distro               1.5.0
# docutils             0.16
# ec2-hibinit-agent    1.0.8
# filelock             3.0.12
# gpg                  1.15.1
# idna                 2.10
# Jinja2               2.11.3
# jmespath             1.0.1
# joblib               1.4.2
# jsonpatch            1.21
# jsonpointer          2.0
# jsonschema           3.2.0
# libcomps             0.1.20
# lockfile             0.12.2
# lxml                 5.3.0
# MarkupSafe           1.1.1
# mysqlclient          1.4.2
# netifaces            0.10.6
# nltk                 3.9.1
# nose                 1.3.4
# oauthlib             3.0.2
# pip                  21.3.1
# ply                  3.11
# prettytable          0.7.2
# prompt-toolkit       3.0.24
# py-dateutil          2.2
# pycparser            2.20
# pyrsistent           0.17.3
# pyserial             3.4
# PySocks              1.7.1
# python-daemon        2.3.0
# python-dateutil      2.8.1
# pytz                 2024.2
# PyYAML               5.4.1
# regex                2021.11.10
# release-notification 1.2
# requests             2.25.1
# rpm                  4.16.1.3
# ruamel.yaml          0.16.6
# ruamel.yaml.clib     0.1.2
# selinux              3.4
# sepolicy             3.4
# setools              4.4.1
# setuptools           59.6.0
# six                  1.13.0
# soupsieve            1.9.5
# support-info         1.0
# systemd-python       235
# tqdm                 4.66.5
# urllib3              1.25.10
# virtualenv           20.4.0
# wcwidth              0.2.5
# wheel                0.37.1
# windmill             1.6
#
# WARNING: The directory '/home/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.

# %%
sc.install_pypi_package("spacy")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Collecting spacy
#   Downloading spacy-3.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
# Collecting thinc<8.4.0,>=8.3.0
#   Downloading thinc-8.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
# Collecting typer<1.0.0,>=0.3.0
#   Downloading typer-0.13.0-py3-none-any.whl (44 kB)
# Collecting weasel<0.5.0,>=0.1.0
#   Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (157 kB)
# Collecting numpy>=1.19.0
#   Downloading numpy-2.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3.9/site-packages (from spacy) (2.25.1)
# Requirement already satisfied: jinja2 in /usr/lib/python3.9/site-packages (from spacy) (2.11.3)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4
#   Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting packaging>=20.0
#   Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib64/python3.9/site-packages (from spacy) (4.66.5)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Requirement already satisfied: setuptools in ./tmp/spark-b1a402d5-c854-4ba0-afa1-cf62fde5d119/lib/python3.9/site-packages (from spacy) (59.6.0)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.4.1-py3-none-any.whl (182 kB)
# Collecting language-data>=1.2
#   Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
# Collecting typing-extensions>=4.6.1
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting pydantic-core==2.23.4
#   Downloading pydantic_core-2.23.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Collecting blis<1.1.0,>=1.0.0
#   Downloading blis-1.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.2 MB)
# Collecting rich>=10.11.0
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib64/python3.9/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Downloading cloudpathlib-0.20.0-py3-none-any.whl (52 kB)
# Collecting smart-open<8.0.0,>=5.2.1
#   Downloading smart_open-7.0.5-py3-none-any.whl (61 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/lib64/python3.9/site-packages (from jinja2->spacy) (1.1.1)
# Collecting marisa-trie>=0.7.7
#   Downloading marisa_trie-1.2.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting wrapt
#   Downloading wrapt-1.16.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: typing-extensions, mdurl, pygments, pydantic-core, markdown-it-py, catalogue, annotated-types, wrapt, srsly, shellingham, rich, pydantic, numpy, murmurhash, marisa-trie, cymem, wasabi, typer, smart-open, preshed, packaging, language-data, confection, cloudpathlib, blis, weasel, thinc, spacy-loggers, spacy-legacy, langcodes, spacy
# Successfully installed annotated-types-0.7.0 blis-1.0.1 catalogue-2.0.10 cloudpathlib-0.20.0 confection-0.1.5 cymem-2.0.8 langcodes-3.4.1 language-data-1.2.0 marisa-trie-1.2.1 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.10 numpy-2.0.2 packaging-24.2 preshed-3.0.9 pydantic-2.9.2 pydantic-core-2.23.4 pygments-2.18.0 rich-13.9.4 shellingham-1.5.4 smart-open-7.0.5 spacy-3.8.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.3.2 typer-0.13.0 typing-extensions-4.12.2 wasabi-1.1.3 weasel-0.4.1 wrapt-1.16.0
#
# WARNING: The directory '/home/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.

# %%
sc.getConf().get("spark.pyspark.virtualenv.enabled")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 'true'

# %%
sc.list_packages()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Package              Version
# -------------------- ----------
# annotated-types      0.7.0
# appdirs              1.4.4
# attrs                20.3.0
# aws-cfn-bootstrap    2.0
# awscli               2.15.30
# awscrt               0.19.19
# Babel                2.9.1
# beautifulsoup4       4.9.3
# blis                 1.0.1
# boto                 2.49.0
# catalogue            2.0.10
# cffi                 1.14.5
# chardet              4.0.0
# chevron              0.13.1
# click                8.1.7
# cloud-init           22.2.2
# cloudpathlib         0.20.0
# colorama             0.4.4
# confection           0.1.5
# configobj            5.0.6
# cryptography         36.0.1
# cymem                2.0.8
# dbus-python          1.2.18
# distlib              0.3.1
# distro               1.5.0
# docutils             0.16
# ec2-hibinit-agent    1.0.8
# filelock             3.0.12
# gpg                  1.15.1
# idna                 2.10
# Jinja2               2.11.3
# jmespath             1.0.1
# joblib               1.4.2
# jsonpatch            1.21
# jsonpointer          2.0
# jsonschema           3.2.0
# langcodes            3.4.1
# language_data        1.2.0
# libcomps             0.1.20
# lockfile             0.12.2
# lxml                 5.3.0
# marisa-trie          1.2.1
# markdown-it-py       3.0.0
# MarkupSafe           1.1.1
# mdurl                0.1.2
# murmurhash           1.0.10
# mysqlclient          1.4.2
# netifaces            0.10.6
# nltk                 3.9.1
# nose                 1.3.4
# numpy                2.0.2
# oauthlib             3.0.2
# packaging            24.2
# pip                  21.3.1
# ply                  3.11
# preshed              3.0.9
# prettytable          0.7.2
# prompt-toolkit       3.0.24
# py-dateutil          2.2
# pycparser            2.20
# pydantic             2.9.2
# pydantic_core        2.23.4
# Pygments             2.18.0
# pyrsistent           0.17.3
# pyserial             3.4
# PySocks              1.7.1
# python-daemon        2.3.0
# python-dateutil      2.8.1
# pytz                 2024.2
# PyYAML               5.4.1
# regex                2021.11.10
# release-notification 1.2
# requests             2.25.1
# rich                 13.9.4
# rpm                  4.16.1.3
# ruamel.yaml          0.16.6
# ruamel.yaml.clib     0.1.2
# selinux              3.4
# sepolicy             3.4
# setools              4.4.1
# setuptools           59.6.0
# shellingham          1.5.4
# six                  1.13.0
# smart-open           7.0.5
# soupsieve            1.9.5
# spacy                3.8.2
# spacy-legacy         3.0.12
# spacy-loggers        1.0.5
# srsly                2.4.8
# support-info         1.0
# systemd-python       235
# thinc                8.3.2
# tqdm                 4.66.5
# typer                0.13.0
# typing_extensions    4.12.2
# urllib3              1.25.10
# virtualenv           20.4.0
# wasabi               1.1.3
# wcwidth              0.2.5
# weasel               0.4.1
# wheel                0.37.1
# windmill             1.6
# wrapt                1.16.0
#
# WARNING: The directory '/home/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.

# %%
sc.uninstall_package("spacy")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Found existing installation: spacy 3.8.2
# Uninstalling spacy-3.8.2:
#   Successfully uninstalled spacy-3.8.2
#
# WARNING: The directory '/home/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.

# %%
sc.list_packages()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Package              Version
# -------------------- ----------
# annotated-types      0.7.0
# appdirs              1.4.4
# attrs                20.3.0
# aws-cfn-bootstrap    2.0
# awscli               2.15.30
# awscrt               0.19.19
# Babel                2.9.1
# beautifulsoup4       4.9.3
# blis                 1.0.1
# boto                 2.49.0
# catalogue            2.0.10
# cffi                 1.14.5
# chardet              4.0.0
# chevron              0.13.1
# click                8.1.7
# cloud-init           22.2.2
# cloudpathlib         0.20.0
# colorama             0.4.4
# confection           0.1.5
# configobj            5.0.6
# cryptography         36.0.1
# cymem                2.0.8
# dbus-python          1.2.18
# distlib              0.3.1
# distro               1.5.0
# docutils             0.16
# ec2-hibinit-agent    1.0.8
# filelock             3.0.12
# gpg                  1.15.1
# idna                 2.10
# Jinja2               2.11.3
# jmespath             1.0.1
# joblib               1.4.2
# jsonpatch            1.21
# jsonpointer          2.0
# jsonschema           3.2.0
# langcodes            3.4.1
# language_data        1.2.0
# libcomps             0.1.20
# lockfile             0.12.2
# lxml                 5.3.0
# marisa-trie          1.2.1
# markdown-it-py       3.0.0
# MarkupSafe           1.1.1
# mdurl                0.1.2
# murmurhash           1.0.10
# mysqlclient          1.4.2
# netifaces            0.10.6
# nltk                 3.9.1
# nose                 1.3.4
# numpy                2.0.2
# oauthlib             3.0.2
# packaging            24.2
# pip                  21.3.1
# ply                  3.11
# preshed              3.0.9
# prettytable          0.7.2
# prompt-toolkit       3.0.24
# py-dateutil          2.2
# pycparser            2.20
# pydantic             2.9.2
# pydantic_core        2.23.4
# Pygments             2.18.0
# pyrsistent           0.17.3
# pyserial             3.4
# PySocks              1.7.1
# python-daemon        2.3.0
# python-dateutil      2.8.1
# pytz                 2024.2
# PyYAML               5.4.1
# regex                2021.11.10
# release-notification 1.2
# requests             2.25.1
# rich                 13.9.4
# rpm                  4.16.1.3
# ruamel.yaml          0.16.6
# ruamel.yaml.clib     0.1.2
# selinux              3.4
# sepolicy             3.4
# setools              4.4.1
# setuptools           59.6.0
# shellingham          1.5.4
# six                  1.13.0
# smart-open           7.0.5
# soupsieve            1.9.5
# spacy-legacy         3.0.12
# spacy-loggers        1.0.5
# srsly                2.4.8
# support-info         1.0
# systemd-python       235
# thinc                8.3.2
# tqdm                 4.66.5
# typer                0.13.0
# typing_extensions    4.12.2
# urllib3              1.25.10
# virtualenv           20.4.0
# wasabi               1.1.3
# wcwidth              0.2.5
# weasel               0.4.1
# wheel                0.37.1
# windmill             1.6
# wrapt                1.16.0
#
# WARNING: The directory '/home/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you should use sudo's -H flag.
